# %%
#Search engine
def read_csv (csvsource):
  import pandas as pd  # For data handling

  df = pd.read_csv(csvsource)
  return df

def full_cleaning(df):
  import re  # For preprocessing
  import pandas as pd  # For data handling
  from time import time  # To time our operations
  from collections import defaultdict  # For word frequency

  import spacy  # For preprocessing

  import logging  # Setting up the loggings to monitor gensim
  logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

  nlp = spacy.load("en_core_web_sm", disable=['ner', 'parser'])
  brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df['title'])
  t = time()
  txt = [sub_cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_threads=-1)]
  print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
  df_clean = pd.DataFrame({'clean': txt})
  print('Finish cleaning')
  return df_clean

def sub_cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)

def learn_relation_keyword(df_clean):
  import re  # For preprocessing
  import pandas as pd  # For data handling
  from time import time  # To time our operations
  from collections import defaultdict  # For word frequency

  import spacy  # For preprocessing

  import logging  # Setting up the loggings to monitor gensim
  logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)
  from gensim.models.phrases import Phrases, Phraser
  sent = [str(row).split() for row in df_clean['clean']]
  phrases = Phrases(sent, min_count=30, progress_per=10000)
  bigram = Phraser(phrases)
  sentences = bigram[sent]
  word_freq = defaultdict(int)
  for sent in sentences:
      for i in sent:
          word_freq[i] += 1
  sorted(word_freq, key=word_freq.get, reverse=True)
  
  #train
  import multiprocessing

  from gensim.models import Word2Vec
  cores = multiprocessing.cpu_count()
  w2v_model = Word2Vec(min_count=20,
                     window=2,
                     vector_size=300,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)
  t = time()
  w2v_model.build_vocab(sentences, progress_per=10000)
  print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))

  t = time()
  w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)
  w2v_model.save('keyword2vec_model.bin')
  print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))

  w2v_model.save('/content/keyword2vec_model.bin')
  print('Finish learning, save model as keyword2vec_model.bin')

def learn_relation_title(modelpath = './keyword2vec_model.bin' ):
  import multiprocessing
  from coordle.backend.coordle_backend import QueryAppenderIndex
  from gensim.models import Word2Vec
  cores = multiprocessing.cpu_count()
  w2v_model = Word2Vec.load('/content/keyword2vec_model.bin')
  w2v_model.init_sims(replace=True)
  # To demonstrate how the search engine works, we index on a subset of the documents in the dataframe.
  from coordle.backend import QueryAppenderIndex
  ai_index = QueryAppenderIndex(w2v_model.wv.most_similar, n_similars=1)

  ai_index.build_from_df(
    df,
    'id',
    'title',
    'title', 
    verbose=True, 
    use_multiprocessing=True,
    workers=cores-1
  )
  return ai_index

def search_and_show(ai_index, query, max_results = 48, max_body_length = 500):
    '''Searches using the AI Index and shows the result
    
    Args:
        query: Search query
        max_results: Max results to show for each query    
    '''

    docs, scores, errmsgs = ai_index.search(query)
    
    if errmsgs:
        print('The following errors occurred:', errmsgs)
    else:
      related_id_products = []
      if len(docs) == 0:
        return 'Sorry, no results found.'
      else:
        for doc, score in zip(docs[:max_results], scores[:max_results]):
          print(f'{doc.uid}  {str(doc.title)[:70]:<70}  {score:.4f}')
          print('---')
          related_id_products.append(doc.uid)
        return related_id_products

# %%
df = read_csv('/content/cshop_ml_public_product.csv')

# %%
# !python -m spacy validate
# Out:
# ✔ Loaded compatibility table
#
# ====================== Installed models (spaCy v2.3.5) ======================
# ℹ spaCy installation: /usr/local/lib/python3.7/dist-packages/spacy
#
# TYPE      NAME             MODEL            VERSION
# package   en-core-web-sm   en_core_web_sm   2.3.1   ✔

# %%
# !pip install nltk

# !pip install spacy==2.3.5

# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz

# !pip install pyresparser
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.6.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.62.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2021.11.10)
# Collecting spacy==2.3.5
#   Using cached spacy-2.3.5-cp37-cp37m-manylinux2014_x86_64.whl (10.4 MB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (2.0.6)
# Collecting catalogue<1.1.0,>=0.0.7
#   Using cached catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (57.4.0)
# Collecting thinc<7.5.0,>=7.4.1
#   Using cached thinc-7.4.5-cp37-cp37m-manylinux2014_x86_64.whl (1.0 MB)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (0.8.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (1.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (1.19.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (1.0.6)
# Collecting srsly<1.1.0,>=1.0.2
#   Using cached srsly-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (184 kB)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (3.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy==2.3.5) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy==2.3.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy==2.3.5) (3.10.0.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (2.10)
# Installing collected packages: srsly, catalogue, thinc, spacy
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.2
#     Uninstalling srsly-2.4.2:
#       Successfully uninstalled srsly-2.4.2
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.6
#     Uninstalling catalogue-2.0.6:
#       Successfully uninstalled catalogue-2.0.6
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.13
#     Uninstalling thinc-8.0.13:
#       Successfully uninstalled thinc-8.0.13
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.0.7
#     Uninstalling spacy-3.0.7:
#       Successfully uninstalled spacy-3.0.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scispacy 0.4.0 requires spacy<3.1.0,>=3.0.0, but you have spacy 2.3.5 which is incompatible.
# Successfully installed catalogue-1.0.0 spacy-2.3.5 srsly-1.0.5 thinc-7.4.5
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 7.9 MB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==2.3.1) (2.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (57.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.19.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.1.3)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (7.4.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (0.8.2)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.10.0.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.0.4)
# Requirement already satisfied: pyresparser in /usr/local/lib/python3.7/dist-packages (1.0.6)
# Requirement already satisfied: thinc>=7.0.4 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (7.4.5)
# Requirement already satisfied: pdfminer.six>=20181108 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (20211012)
# Requirement already satisfied: cymem>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.0.6)
# Requirement already satisfied: pytz>=2019.1 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2021.3)
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (3.0.4)
# Requirement already satisfied: pyrsistent>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (0.18.0)
# Requirement already satisfied: docx2txt>=0.7 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (0.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.8.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (1.15.0)
# Requirement already satisfied: spacy>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.3.5)
# Requirement already satisfied: blis>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (0.4.1)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (1.19.5)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (1.1.5)
# Requirement already satisfied: srsly>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (1.0.5)
# Requirement already satisfied: certifi>=2019.6.16 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2021.10.8)
# Requirement already satisfied: tqdm>=4.32.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (4.62.3)
# Requirement already satisfied: preshed>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (3.0.6)
# Requirement already satisfied: sortedcontainers>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.4.0)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (1.25.11)
# Requirement already satisfied: nltk>=3.4.3 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (3.6.5)
# Requirement already satisfied: wasabi>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (0.8.2)
# Requirement already satisfied: pycryptodome>=3.8.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (3.12.0)
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (4.3.1)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (21.2.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.10)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.23.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->pyresparser) (5.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->pyresparser) (3.10.0.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->pyresparser) (4.8.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=3.0.1->pyresparser) (3.6.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.3->pyresparser) (2021.11.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.3->pyresparser) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.3->pyresparser) (1.1.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.7/dist-packages (from pdfminer.six>=20181108->pyresparser) (36.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from preshed>=2.0.1->pyresparser) (1.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.4->pyresparser) (1.1.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.4->pyresparser) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.4->pyresparser) (57.4.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography->pdfminer.six>=20181108->pyresparser) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography->pdfminer.six>=20181108->pyresparser) (2.21)

# %%
df_clean = full_cleaning(df)
learn_relation_keyword(df_clean)
# Out:
# Time to clean up everything: 0.22 mins
# Finish cleaning
# INFO - 02:35:42: collecting all words and their counts
# INFO - 02:35:42: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 02:35:42: PROGRESS: at sentence #10000, processed 115218 words and 18431 word types
# INFO - 02:35:42: PROGRESS: at sentence #20000, processed 212653 words and 50300 word types
# INFO - 02:35:42: collected 62583 token types (unigram + bigrams) from a corpus of 265431 words and 25638 sentences
# INFO - 02:35:42: merged Phrases<62583 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# INFO - 02:35:42: Phrases lifecycle event {'msg': 'built Phrases<62583 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 0.37s', 'datetime': '2021-12-18T02:35:42.451878', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'created'}
# INFO - 02:35:42: exporting phrases from Phrases<62583 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# INFO - 02:35:42: FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<314 phrases, min_count=30, threshold=10.0> from Phrases<62583 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 0.15s', 'datetime': '2021-12-18T02:35:42.613882', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'created'}
# INFO - 02:35:42: Word2Vec lifecycle event {'params': 'Word2Vec(vocab=0, vector_size=300, alpha=0.03)', 'datetime': '2021-12-18T02:35:42.982629', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'created'}
# INFO - 02:35:42: collecting all words and their counts
# INFO - 02:35:42: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 02:35:43: PROGRESS: at sentence #10000, processed 102629 words, keeping 3756 word types
# INFO - 02:35:43: PROGRESS: at sentence #20000, processed 195035 words, keeping 8301 word types
# INFO - 02:35:43: collected 10071 word types from a corpus of 242969 raw words and 25638 sentences
# INFO - 02:35:43: Creating a fresh vocabulary
# INFO - 02:35:43: Word2Vec lifecycle event {'msg': 'effective_min_count=20 retains 2257 unique words (22.41088273259855%% of original 10071, drops 7814)', 'datetime': '2021-12-18T02:35:43.412550', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# INFO - 02:35:43: Word2Vec lifecycle event {'msg': 'effective_min_count=20 leaves 202882 word corpus (83.50118739427664%% of original 242969, drops 40087)', 'datetime': '2021-12-18T02:35:43.414622', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# INFO - 02:35:43: deleting the raw counts dictionary of 10071 items
# INFO - 02:35:43: sample=6e-05 downsamples 1623 most-common words
# INFO - 02:35:43: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 89972.59954242776 word corpus (44.3%% of prior 202882)', 'datetime': '2021-12-18T02:35:43.443220', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# INFO - 02:35:43: estimated required memory for 2257 words and 300 dimensions: 6545300 bytes
# INFO - 02:35:43: resetting layer weights
# INFO - 02:35:43: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2021-12-18T02:35:43.490693', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'build_vocab'}
# INFO - 02:35:43: Word2Vec lifecycle event {'msg': 'training model with 1 workers on 2257 vocabulary and 300 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2 shrink_windows=True', 'datetime': '2021-12-18T02:35:43.493794', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'train'}
# Time to build vocab: 0.01 mins
# INFO - 02:35:44: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:44: EPOCH - 1 : training on 242969 raw words (89641 effective words) took 0.9s, 100584 effective words/s
# INFO - 02:35:45: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:45: EPOCH - 2 : training on 242969 raw words (90069 effective words) took 0.9s, 103840 effective words/s
# INFO - 02:35:46: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:46: EPOCH - 3 : training on 242969 raw words (90094 effective words) took 0.9s, 95072 effective words/s
# INFO - 02:35:47: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:47: EPOCH - 4 : training on 242969 raw words (90072 effective words) took 0.9s, 105511 effective words/s
# INFO - 02:35:47: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:47: EPOCH - 5 : training on 242969 raw words (89913 effective words) took 0.9s, 103785 effective words/s
# INFO - 02:35:48: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:48: EPOCH - 6 : training on 242969 raw words (90123 effective words) took 0.9s, 104102 effective words/s
# INFO - 02:35:49: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:49: EPOCH - 7 : training on 242969 raw words (90189 effective words) took 0.8s, 106472 effective words/s
# INFO - 02:35:50: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:50: EPOCH - 8 : training on 242969 raw words (90231 effective words) took 0.9s, 104791 effective words/s
# INFO - 02:35:51: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:51: EPOCH - 9 : training on 242969 raw words (89922 effective words) took 0.9s, 104316 effective words/s
# INFO - 02:35:52: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:52: EPOCH - 10 : training on 242969 raw words (90080 effective words) took 0.9s, 96612 effective words/s
# INFO - 02:35:53: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:53: EPOCH - 11 : training on 242969 raw words (90256 effective words) took 0.8s, 106657 effective words/s
# INFO - 02:35:54: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:54: EPOCH - 12 : training on 242969 raw words (90265 effective words) took 0.8s, 107773 effective words/s
# INFO - 02:35:54: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:54: EPOCH - 13 : training on 242969 raw words (89893 effective words) took 0.8s, 106230 effective words/s
# INFO - 02:35:55: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:55: EPOCH - 14 : training on 242969 raw words (90207 effective words) took 0.8s, 107537 effective words/s
# INFO - 02:35:56: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:56: EPOCH - 15 : training on 242969 raw words (89889 effective words) took 0.8s, 106494 effective words/s
# INFO - 02:35:57: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:57: EPOCH - 16 : training on 242969 raw words (89887 effective words) took 0.9s, 100236 effective words/s
# INFO - 02:35:58: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:58: EPOCH - 17 : training on 242969 raw words (90096 effective words) took 0.8s, 110676 effective words/s
# INFO - 02:35:59: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:35:59: EPOCH - 18 : training on 242969 raw words (90131 effective words) took 0.8s, 111740 effective words/s
# INFO - 02:36:00: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:00: EPOCH - 19 : training on 242969 raw words (89955 effective words) took 0.8s, 109034 effective words/s
# INFO - 02:36:00: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:00: EPOCH - 20 : training on 242969 raw words (89952 effective words) took 0.8s, 109445 effective words/s
# INFO - 02:36:01: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:01: EPOCH - 21 : training on 242969 raw words (90094 effective words) took 0.8s, 110790 effective words/s
# INFO - 02:36:02: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:02: EPOCH - 22 : training on 242969 raw words (89725 effective words) took 0.8s, 109794 effective words/s
# INFO - 02:36:03: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:03: EPOCH - 23 : training on 242969 raw words (90086 effective words) took 0.9s, 100467 effective words/s
# INFO - 02:36:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:04: EPOCH - 24 : training on 242969 raw words (90049 effective words) took 0.8s, 109082 effective words/s
# INFO - 02:36:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:05: EPOCH - 25 : training on 242969 raw words (90120 effective words) took 0.8s, 110789 effective words/s
# INFO - 02:36:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:05: EPOCH - 26 : training on 242969 raw words (89712 effective words) took 0.8s, 111579 effective words/s
# INFO - 02:36:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:06: EPOCH - 27 : training on 242969 raw words (90011 effective words) took 0.8s, 110747 effective words/s
# INFO - 02:36:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:07: EPOCH - 28 : training on 242969 raw words (90199 effective words) took 0.8s, 108775 effective words/s
# INFO - 02:36:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:08: EPOCH - 29 : training on 242969 raw words (89926 effective words) took 0.9s, 102193 effective words/s
# INFO - 02:36:09: worker thread finished; awaiting finish of 0 more threads
# INFO - 02:36:09: EPOCH - 30 : training on 242969 raw words (89970 effective words) took 0.8s, 109239 effective words/s
# INFO - 02:36:09: Word2Vec lifecycle event {'msg': 'training on 7289070 raw words (2700757 effective words) took 25.8s, 104520 effective words/s', 'datetime': '2021-12-18T02:36:09.337081', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'train'}
# INFO - 02:36:09: Word2Vec lifecycle event {'fname_or_handle': 'keyword2vec_model.bin', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2021-12-18T02:36:09.340019', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'saving'}
# INFO - 02:36:09: not storing attribute cum_table
# INFO - 02:36:09: saved keyword2vec_model.bin
# INFO - 02:36:09: Word2Vec lifecycle event {'fname_or_handle': '/content/keyword2vec_model.bin', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2021-12-18T02:36:09.361557', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'saving'}
# INFO - 02:36:09: not storing attribute cum_table
# INFO - 02:36:09: saved /content/keyword2vec_model.bin
# Time to train the model: 0.43 mins
# Finish learning, save model as keyword2vec_model.bin

# %%
# !pip install coordle
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_lg-0.2.4.tar.gz
# !pip install git+https://github.com/JonasTriki/inf368-exercise-3-coordle.git
# Out:
# Requirement already satisfied: coordle in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.7/dist-packages (from coordle) (1.1.5)
# Requirement already satisfied: spacy-langdetect>=0.1.2 in /usr/local/lib/python3.7/dist-packages (from coordle) (0.1.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from coordle) (1.4.1)
# Requirement already satisfied: gensim>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from coordle) (4.1.2)
# Requirement already satisfied: nltk>=3.4.5 in /usr/local/lib/python3.7/dist-packages (from coordle) (3.6.5)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.7/dist-packages (from coordle) (0.51.2)
# Requirement already satisfied: scispacy>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from coordle) (0.4.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from coordle) (1.19.5)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim>=3.8.1->coordle) (5.2.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.5->coordle) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.5->coordle) (4.62.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.5->coordle) (2021.11.10)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.5->coordle) (1.1.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.45.1->coordle) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.45.1->coordle) (57.4.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.1->coordle) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.1->coordle) (2021.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->coordle) (1.15.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scispacy>=0.2.4->coordle) (2.23.0)
# Collecting spacy<3.1.0,>=3.0.0
#   Using cached spacy-3.0.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.3 MB)
# Requirement already satisfied: pysbd in /usr/local/lib/python3.7/dist-packages (from scispacy>=0.2.4->coordle) (0.3.4)
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.7/dist-packages (from scispacy>=0.2.4->coordle) (1.0.1)
# Requirement already satisfied: nmslib>=1.7.3.6 in /usr/local/lib/python3.7/dist-packages (from scispacy>=0.2.4->coordle) (2.1.1)
# Requirement already satisfied: conllu in /usr/local/lib/python3.7/dist-packages (from scispacy>=0.2.4->coordle) (4.4.1)
# Requirement already satisfied: pybind11<2.6.2 in /usr/local/lib/python3.7/dist-packages (from nmslib>=1.7.3.6->scispacy>=0.2.4->coordle) (2.6.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from nmslib>=1.7.3.6->scispacy>=0.2.4->coordle) (5.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy>=0.2.4->coordle) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy>=0.2.4->coordle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy>=0.2.4->coordle) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy>=0.2.4->coordle) (1.25.11)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.3->scispacy>=0.2.4->coordle) (3.0.0)
# Collecting catalogue<2.1.0,>=2.0.4
#   Using cached catalogue-2.0.6-py3-none-any.whl (17 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (1.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (3.10.0.2)
# Collecting thinc<8.1.0,>=8.0.3
#   Using cached thinc-8.0.13-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (628 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (1.8.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (0.3.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (3.0.6)
# Collecting srsly<3.0.0,>=2.4.1
#   Using cached srsly-2.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (451 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (21.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (0.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (3.0.8)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (0.4.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (3.0.6)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from spacy-langdetect>=0.1.2->coordle) (3.6.4)
# Requirement already satisfied: langdetect==1.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy-langdetect>=0.1.2->coordle) (1.0.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle) (2.0.1)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->spacy-langdetect>=0.1.2->coordle) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->spacy-langdetect>=0.1.2->coordle) (1.11.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->spacy-langdetect>=0.1.2->coordle) (21.2.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->spacy-langdetect>=0.1.2->coordle) (8.12.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->spacy-langdetect>=0.1.2->coordle) (1.4.0)
# Installing collected packages: catalogue, srsly, thinc, spacy
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.5
#     Uninstalling thinc-7.4.5:
#       Successfully uninstalled thinc-7.4.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.3.5
#     Uninstalling spacy-2.3.5:
#       Successfully uninstalled spacy-2.3.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 2.3.1 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.7 which is incompatible.
# Successfully installed catalogue-2.0.6 spacy-3.0.7 srsly-2.4.2 thinc-8.0.13
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_lg-0.2.4.tar.gz
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_lg-0.2.4.tar.gz (500.6 MB)
# Requirement already satisfied: spacy>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from en-core-sci-lg==0.2.4) (3.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (0.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (4.62.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (2.23.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (2.0.6)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (0.3.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (8.0.13)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (1.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (3.10.0.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (57.4.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (0.6.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (2.4.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (3.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (2.0.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (21.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.1->en-core-sci-lg==0.2.4) (2.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy>=2.2.1->en-core-sci-lg==0.2.4) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy>=2.2.1->en-core-sci-lg==0.2.4) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy>=2.2.1->en-core-sci-lg==0.2.4) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->en-core-sci-lg==0.2.4) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->en-core-sci-lg==0.2.4) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->en-core-sci-lg==0.2.4) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->en-core-sci-lg==0.2.4) (3.0.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy>=2.2.1->en-core-sci-lg==0.2.4) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=2.2.1->en-core-sci-lg==0.2.4) (2.0.1)
# Collecting git+https://github.com/JonasTriki/inf368-exercise-3-coordle.git
#   Cloning https://github.com/JonasTriki/inf368-exercise-3-coordle.git to /tmp/pip-req-build-oq8dhs0f
#   Running command git clone -q https://github.com/JonasTriki/inf368-exercise-3-coordle.git /tmp/pip-req-build-oq8dhs0f
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from coordle==0.0.1) (1.19.5)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.7/dist-packages (from coordle==0.0.1) (1.1.5)
# Requirement already satisfied: scispacy>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from coordle==0.0.1) (0.4.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from coordle==0.0.1) (1.4.1)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.7/dist-packages (from coordle==0.0.1) (0.51.2)
# Requirement already satisfied: gensim>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from coordle==0.0.1) (4.1.2)
# Requirement already satisfied: nltk>=3.4.5 in /usr/local/lib/python3.7/dist-packages (from coordle==0.0.1) (3.6.5)
# Requirement already satisfied: spacy-langdetect>=0.1.2 in /usr/local/lib/python3.7/dist-packages (from coordle==0.0.1) (0.1.2)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim>=3.8.1->coordle==0.0.1) (5.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.5->coordle==0.0.1) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.5->coordle==0.0.1) (2021.11.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.5->coordle==0.0.1) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.5->coordle==0.0.1) (4.62.3)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.45.1->coordle==0.0.1) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.45.1->coordle==0.0.1) (57.4.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.1->coordle==0.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.1->coordle==0.0.1) (2021.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->coordle==0.0.1) (1.15.0)
# Requirement already satisfied: conllu in /usr/local/lib/python3.7/dist-packages (from scispacy>=0.2.4->coordle==0.0.1) (4.4.1)
# Requirement already satisfied: pysbd in /usr/local/lib/python3.7/dist-packages (from scispacy>=0.2.4->coordle==0.0.1) (0.3.4)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from scispacy>=0.2.4->coordle==0.0.1) (3.0.7)
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.7/dist-packages (from scispacy>=0.2.4->coordle==0.0.1) (1.0.1)
# Requirement already satisfied: nmslib>=1.7.3.6 in /usr/local/lib/python3.7/dist-packages (from scispacy>=0.2.4->coordle==0.0.1) (2.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scispacy>=0.2.4->coordle==0.0.1) (2.23.0)
# Requirement already satisfied: pybind11<2.6.2 in /usr/local/lib/python3.7/dist-packages (from nmslib>=1.7.3.6->scispacy>=0.2.4->coordle==0.0.1) (2.6.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from nmslib>=1.7.3.6->scispacy>=0.2.4->coordle==0.0.1) (5.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy>=0.2.4->coordle==0.0.1) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy>=0.2.4->coordle==0.0.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy>=0.2.4->coordle==0.0.1) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy>=0.2.4->coordle==0.0.1) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.3->scispacy>=0.2.4->coordle==0.0.1) (3.0.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (2.4.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (0.3.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (1.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (3.10.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (21.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (3.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (3.0.8)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (8.0.13)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (0.6.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (1.8.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (0.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (0.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (2.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (3.0.6)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from spacy-langdetect>=0.1.2->coordle==0.0.1) (3.6.4)
# Requirement already satisfied: langdetect==1.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy-langdetect>=0.1.2->coordle==0.0.1) (1.0.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->scispacy>=0.2.4->coordle==0.0.1) (2.0.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->spacy-langdetect>=0.1.2->coordle==0.0.1) (8.12.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->spacy-langdetect>=0.1.2->coordle==0.0.1) (1.4.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->spacy-langdetect>=0.1.2->coordle==0.0.1) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->spacy-langdetect>=0.1.2->coordle==0.0.1) (1.11.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->spacy-langdetect>=0.1.2->coordle==0.0.1) (21.2.0)

# %%
ai_index = learn_relation_title('/content/keyword2vec_model.bin')
products = search_and_show(ai_index, 'apple')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_core_sci_lg' (0.2.4) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   """Load JSON language data using the given path as a base. If the provided
# INFO - 02:37:17: loading Word2Vec object from /content/keyword2vec_model.bin
# INFO - 02:37:17: loading wv recursively from /content/keyword2vec_model.bin.wv.* with mmap=None
# INFO - 02:37:17: setting ignored attribute cum_table to None
# INFO - 02:37:17: Word2Vec lifecycle event {'fname': '/content/keyword2vec_model.bin', 'datetime': '2021-12-18T02:37:17.749418', 'gensim': '4.1.2', 'python': '3.7.12 (default, Sep 10 2021, 00:21:48) \n[GCC 7.5.0]', 'platform': 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'loaded'}
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:90: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
# WARNING - 02:37:17: destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# Text cleaning initilized on 1 workers
# Cleaning texts: 100%|██████████| 25638/25638 [00:09<00:00, 2716.59it/s]
# Adding to index: 100%|██████████| 25638/25638 [00:19<00:00, 1323.20it/s]
# 15417  Philodendron Apple Green                                                1.5048
# ---
# 13843  HOUZE - 6 Tier 'Apple' Knock Down Cabinet                               0.9029
# ---
# 20027  AVALON Apple Cider Vinegar Gummies 60s                                  0.9029
# ---
# 13462  HOUZE - 6 Tier 'Apple' Knock Down Cabinet                               0.9029
# ---
# 13792  HOUZE - 5 Tier 'Apple' Knock Down Cabinet                               0.9029
# ---
# 13385  HOUZE - 5 Tier 'Apple' Knock Down Cabinet                               0.9029
# ---
# 20078  21st Century Apple Cider Vinegar 90 Gummies                             0.7524
# ---
# 25590  SKINARMA Tekubi Apple Watch Strap 42/44mm                               0.7524
# ---
# 25181  SKINARMA Tekubi Apple Watch Strap 42/44mm                               0.7524
# ---
# 25216  NOMAD Rugged Strap(FKM) for Apple Watch 45mm/44mm/42mm                  0.7524
# ---
# 25631  NOMAD Rugged Strap(FKM) for Apple Watch 45mm/44mm/42mm                  0.7524
# ---
# 25543  UAG Apple Watch Strap Series 7 / SE / 6 / 5 / 4 / 3 / 2 / 1 (45mm / 44  0.6449
# ---
# 19654  [RITZ APPLE STRUDEL & PASTRY] Strudel Full Loaf                         0.6449
# ---
# 2141  Spigen Apple Airpods Pro Case Tough Armor                               0.6449
# ---
# 18845  [RITZ APPLE STRUDEL & PASTRY] Strudel Full Loaf                         0.6449
# ---
# 23651  TAKA Jewellery 999 Pure Gold Mini Apple Charm                           0.6449
# ---
# 2391  RhinoShield CrashGuard NX RIM for Apple Watch 42mm/44mm                 0.6449
# ---
# 19774  [RITZ APPLE STRUDEL & PASTRY] Strudel Half Loaf                         0.6449
# ---
# 19365  [RITZ APPLE STRUDEL & PASTRY] Strudel Half Loaf                         0.6449
# ---
# 643  Ankndo Stylus Pen Apple Pencil For iPad Android Tablet Screen Pen For   0.6449
# ---
# 1978  RhinoShield CrashGuard NX RIM for Apple Watch 42mm/44mm                 0.6449
# ---
# 812  RhinoShield CrashGuard NX RIM for Apple Watch 42mm/44mm                 0.6449
# ---
# 1728  Spigen Apple Airpods Pro Case Tough Armor                               0.6449
# ---
# 1311  Spigen Apple Airpods Pro Case Tough Armor                               0.6449
# ---
# 210  Ankndo Stylus Pen Apple Pencil For iPad Android Tablet Screen Pen For   0.6449
# ---
# 1061  Ankndo Stylus Pen Apple Pencil For iPad Android Tablet Screen Pen For   0.6449
# ---
# 116  Spigen Apple Airpods Pro Case Tough Armor                               0.6449
# ---
# 18969  [RITZ APPLE STRUDEL & PASTRY] Strudel Half Loaf                         0.6449
# ---
# 361  RhinoShield CrashGuard NX RIM for Apple Watch 42mm/44mm                 0.6449
# ---
# 1206  RhinoShield CrashGuard NX RIM for Apple Watch 42mm/44mm                 0.6449
# ---
# 519  Spigen Apple Airpods Pro Case Tough Armor                               0.6449
# ---
# 19247  [RITZ APPLE STRUDEL & PASTRY] Strudel Full Loaf                         0.6449
# ---
# 24448  TAKA Jewellery 999 Pure Gold Mini Apple Charm                           0.6449
# ---
# 1571  RhinoShield CrashGuard NX RIM for Apple Watch 42mm/44mm                 0.6449
# ---
# 25126  UAG Apple Watch Strap Series 7 / SE / 6 / 5 / 4 / 3 / 2 / 1 (45mm / 44  0.6449
# ---
# 943  Spigen Apple Airpods Pro Case Tough Armor                               0.6449
# ---
# 24977  UAG Apple Watch Strap Series 7 / SE / 6 / 5 / 4 / 3 / 2 / 1 (45mm / 44  0.6019
# ---
# 25392  UAG Apple Watch Strap Series 7 / SE / 6 / 5 / 4 / 3 / 2 / 1 (45mm / 44  0.6019
# ---
# 354  RhinoShield CrashGuard NX for Apple Watch Series 4/5/6/SE 44mm          0.5643
# ---
# 24949  UNIQ Aspen Braided Apple Watch Strap 40 / 38mm or 44 / 42mm             0.5643
# ---
# 23576  Manhattan Portage Big Apple Backpack (MD) W/Divider – Black             0.5643
# ---
# 25447  X-Doria Defense Edge Case for Apple Watch Series 4-7 41mm/40mm          0.5643
# ---
# 1929  RhinoShield CrashGuard NX for Apple Watch Series 4/5/6/SE 44mm          0.5643
# ---
# 2347  RhinoShield CrashGuard NX for Apple Watch Series 4/5/6/SE 44mm          0.5643
# ---
# 21009  Clinically Proven LEAN UP Calorie Burning Juice - Cranberry Apple       0.5643
# ---
# 25027  X-Doria Defense Edge Case for Apple Watch Series 4-7 41mm/40mm          0.5643
# ---
# 25592  Coach Apple Watch® Strap Blue Rubber 42mm Men 14700045                  0.5643
# ---
# 1520  RhinoShield CrashGuard NX for Apple Watch Series 4/5/6/SE 44mm          0.5643
# ---

# %%
products = search_and_show(ai_index, 'Naruto')
# Out:
# 16512  Ossayi Remote Control 3D LED Light  Naruto Table Lamps 16 Color USB Ba  100.0000
# ---

# %%
products
# Out:
# [15417,
#  13843,
#  20027,
#  13462,
#  13792,
#  13385,
#  20078,
#  25590,
#  25181,
#  25216,
#  25631,
#  25543,
#  19654,
#  2141,
#  18845,
#  23651,
#  2391,
#  19774,
#  19365,
#  643,
#  1978,
#  812,
#  1728,
#  1311,
#  210,
#  1061,
#  116,
#  18969,
#  361,
#  1206,
#  519,
#  19247,
#  24448,
#  1571,
#  25126,
#  943,
#  24977,
#  25392,
#  354,
#  24949,
#  23576,
#  25447,
#  1929,
#  2347,
#  21009,
#  25027,
#  25592,
#  1520]
